# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
branch_visits = pd.read_csv("../data/cleaned_files/tpl_branch_visits_2012_2022_clean.csv")
branch_visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NBHDNo      1085 non-null   int64
#  1   NBHDName    1085 non-null   object
#  2   BranchCode  1085 non-null   object
#  3   BranchName  1085 non-null   object
#  4   Year        1085 non-null   int64
#  5   Visits      1085 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 51.0+ KB

# %%
branch_reg = pd.read_csv("../data/cleaned_files/tpl_branch_registrations_2012_2022_clean.csv")
branch_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NBHDNo         1095 non-null   int64
#  1   NBHDName       1095 non-null   object
#  2   BranchCode     1095 non-null   object
#  3   BranchName     1095 non-null   object
#  4   Year           1095 non-null   int64
#  5   Registrations  1095 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 51.5+ KB

# %%
branch_circ = pd.read_csv("../data/cleaned_files/tpl_branch_circulation_2012_2022_clean.csv")
branch_circ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NBHDNo       1095 non-null   int64
#  1   NBHDName     1095 non-null   object
#  2   BranchCode   1095 non-null   object
#  3   BranchName   1095 non-null   object
#  4   Year         1095 non-null   int64
#  5   Circulation  1095 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 51.5+ KB

# %%
branch_wrkstn_use = pd.read_csv("../data/cleaned_files/tpl_branch_workstation_use_2012_2022_clean.csv")
branch_wrkstn_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1081 entries, 0 to 1080
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NBHDNo      1081 non-null   int64
#  1   NBHDName    1081 non-null   object
#  2   BranchCode  1081 non-null   object
#  3   BranchName  1081 non-null   object
#  4   Year        1081 non-null   int64
#  5   Sessions    1081 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 50.8+ KB

# %%
branch_lvl_stats_1 = pd.merge(branch_visits, branch_reg, on=['NBHDNo', 'NBHDName', 'BranchCode', 'BranchName','Year'], how = 'outer')
branch_lvl_stats_1
# Out:
#       NBHDNo                           NBHDName BranchCode        BranchName  \
# 0          2  Mount Olive-Silverstone-Jamestown         AB            Albion
# 1        120                Clairlea-Birchmount        ACD   Albert Campbell
# 2         20                          Alderwood         AD         Alderwood
# 3        118             Tam O'Shanter-Sullivan         AG         Agincourt
# 4         39               Bedford Park-Nortown         AH    Armour Heights
# ...      ...                                ...        ...               ...
# 1090     170                 Yonge-Bay Corridor         CH         City Hall
# 1091      99                Mount Pleasant East         MP    Mount Pleasant
# 1092      87                  High Park-Swansea         SW  Swansea Memorial
# 1093      96                          Casa Loma         WY          Wychwood
# 1094      99                Mount Pleasant East         MP    Mount Pleasant
#
#       Year    Visits  Registrations
# ...

# %%
branch_lvl_stats_2 = pd.merge(branch_lvl_stats_1, branch_circ, on=['NBHDNo', 'NBHDName', 'BranchCode', 'BranchName','Year'], how = 'outer')
branch_lvl_stats_2
# Out:
#       NBHDNo                           NBHDName BranchCode        BranchName  \
# 0          2  Mount Olive-Silverstone-Jamestown         AB            Albion
# 1        120                Clairlea-Birchmount        ACD   Albert Campbell
# 2         20                          Alderwood         AD         Alderwood
# 3        118             Tam O'Shanter-Sullivan         AG         Agincourt
# 4         39               Bedford Park-Nortown         AH    Armour Heights
# ...      ...                                ...        ...               ...
# 1090     170                 Yonge-Bay Corridor         CH         City Hall
# 1091      99                Mount Pleasant East         MP    Mount Pleasant
# 1092      87                  High Park-Swansea         SW  Swansea Memorial
# 1093      96                          Casa Loma         WY          Wychwood
# 1094      99                Mount Pleasant East         MP    Mount Pleasant
#
# ...

# %%
branch_lvl_stats_3 = pd.merge(branch_lvl_stats_2, branch_wrkstn_use, on=['NBHDNo', 'NBHDName', 'BranchCode', 'BranchName','Year'], how = 'outer')
branch_lvl_stats_3
# Out:
#       NBHDNo                           NBHDName BranchCode        BranchName  \
# 0          2  Mount Olive-Silverstone-Jamestown         AB            Albion
# 1        120                Clairlea-Birchmount        ACD   Albert Campbell
# 2         20                          Alderwood         AD         Alderwood
# 3        118             Tam O'Shanter-Sullivan         AG         Agincourt
# 4         39               Bedford Park-Nortown         AH    Armour Heights
# ...      ...                                ...        ...               ...
# 1090     170                 Yonge-Bay Corridor         CH         City Hall
# 1091      99                Mount Pleasant East         MP    Mount Pleasant
# 1092      87                  High Park-Swansea         SW  Swansea Memorial
# 1093      96                          Casa Loma         WY          Wychwood
# 1094      99                Mount Pleasant East         MP    Mount Pleasant
#
# ...

# %%
# Convert 'NBHDNo' to string and add leading zeros
branch_lvl_stats_3['NBHDNo'] = branch_lvl_stats_3['NBHDNo'].apply(lambda x: str(x).zfill(3))
branch_lvl_stats_3
# Out:
#      NBHDNo                           NBHDName BranchCode        BranchName  \
# 0       002  Mount Olive-Silverstone-Jamestown         AB            Albion
# 1       120                Clairlea-Birchmount        ACD   Albert Campbell
# 2       020                          Alderwood         AD         Alderwood
# 3       118             Tam O'Shanter-Sullivan         AG         Agincourt
# 4       039               Bedford Park-Nortown         AH    Armour Heights
# ...     ...                                ...        ...               ...
# 1090    170                 Yonge-Bay Corridor         CH         City Hall
# 1091    099                Mount Pleasant East         MP    Mount Pleasant
# 1092    087                  High Park-Swansea         SW  Swansea Memorial
# 1093    096                          Casa Loma         WY          Wychwood
# 1094    099                Mount Pleasant East         MP    Mount Pleasant
#
# ...

# %%
branch_lvl_stats_3 = branch_lvl_stats_3.fillna(0)

# %%
branch_lvl_stats = branch_lvl_stats_3.copy()

# %%
branch_lvl_stats.to_csv('../data/cleaned_files/branch_lvl_stats.csv', index=False)
